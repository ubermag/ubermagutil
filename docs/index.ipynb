# %% [markdown]
# # Tutorials
#
# ## General information:
#
# - [Installation, testing, and update](installation-testing-update.ipynb)
# - [Support, License, How to cite, and Acknowledgements](other.ipynb)
#
# ## Typesystem
#
# - [Imposing `typesystem` on a class](imposing-typesystem.ipynb)
# - [Constant attributes](constant-attributes.ipynb)
# - [`Parameter` descriptor](parameter-descriptor.ipynb)
# - [Defining `otherwise` type](otherwise-type.ipynb)
#
# ## Inheriting doc-strings
#
# - [`inherit_docs` decorator](inherit-docs.ipynb)
#
# ## SI prefix
#
# - [Extracting SI prefix](si-prefix.ipynb)
